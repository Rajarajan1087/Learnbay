# %% [markdown]
# <a href="https://colab.research.google.com/github/Rajarajan1087/Learnbay/blob/main/Python/Class_04_Python_Programming_Components_Data_Types.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Python Programming Components
# Literals -
# Identifiers - Variables and Constants
# Reserved Words or Keywords
# Blocks and INdentation
# Expressions and Statements
# Comments
# Escape Sequences

# %%
name, value = 'Python', 10
print(name, value)
num = 10
print(num)
# Out:
# Python 10
# 10

# %%
# Identifiers - A name given to a variable, constant, function, class & object etc.
# Rules of defining th identifiers:
  - Allowed characters - A-Z, a-z, 0-9, _
  - Not allowed charcters - Speical Symbols, space characters, -
  - Identifiers can not start with a number
  - Identifiers are case-sensitive

# %%
# my_num = 10
# my num = 10
num1 = 100
# 1num = 200

num = 10
NUm = 100
NUM = 200
print(num, NUm, NUM)
print(NUm)
# Out:
# 10 100 200
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_16359/3942349147.py in <cell line: 0>()
#       8 NUM = 200
#       9 print(num, NUm, NUM)
# ---> 10 print(nuM)
#
# NameError: name 'nuM' is not defined

# %%
# Components,
# Data Types
# Operators
# Strings
# Conditions and LOOps
# list

# %%
# Recommendations
# 1. Keywords or Reserved words shouold not be used as an identifier
# 2. Do not take lengthy identifier
# 3. Constant name should be named using CAPITALCASELETTERS
# 4. Identifiers sahould not start and end with __.
# 5. class name should use PascalCaseNotation and function or method name should use camelCaseNotation.

# %%
import keyword
print(len(keyword.kwlist))
print(keyword.softkwlist)
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break',
#  'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally',
#  'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal',
#  'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# for var in iterable:
#   code
#   code

# for = 10

# FOR = 100
# Out:
# 35
# ['_', 'case', 'match', 'type']

# %%
a = 10
# dir(a)
print(a+2)
print(a.__add__(2))
print(dir(a))
# Out:
# 12
# 12
# ['__abs__', '__add__', '__and__', '__bool__', '__ceil__', '__class__', '__delattr__', '__dir__', '__divmod__', '__doc__', '__eq__', '__float__', '__floor__', '__floordiv__', '__format__', '__ge__', '__getattribute__', '__getnewargs__', '__getstate__', '__gt__', '__hash__', '__index__', '__init__', '__init_subclass__', '__int__', '__invert__', '__le__', '__lshift__', '__lt__', '__mod__', '__mul__', '__ne__', '__neg__', '__new__', '__or__', '__pos__', '__pow__', '__radd__', '__rand__', '__rdivmod__', '__reduce__', '__reduce_ex__', '__repr__', '__rfloordiv__', '__rlshift__', '__rmod__', '__rmul__', '__ror__', '__round__', '__rpow__', '__rrshift__', '__rshift__', '__rsub__', '__rtruediv__', '__rxor__', '__setattr__', '__sizeof__', '__str__', '__sub__', '__subclasshook__', '__truediv__', '__trunc__', '__xor__', 'as_integer_ratio', 'bit_count', 'bit_length', 'conjugate', 'denominator', 'from_bytes', 'imag', 'is_integer', 'numerator', 'real', 'to_bytes']

# %%
import numpy as np
print(dir(np))
# Out:
# ['False_', 'ScalarType', 'True_', '_CopyMode', '_NoValue', '__NUMPY_SETUP__', '__all__', '__array_api_version__', '__builtins__', '__cached__', '__config__', '__dir__', '__doc__', '__expired_attributes__', '__file__', '__former_attrs__', '__future_scalars__', '__getattr__', '__loader__', '__name__', '__numpy_submodules__', '__package__', '__path__', '__spec__', '__version__', '_core', '_distributor_init', '_expired_attrs_2_0', '_get_promotion_state', '_globals', '_int_extended_msg', '_mat', '_msg', '_no_nep50_warning', '_pyinstaller_hooks_dir', '_pytesttester', '_set_promotion_state', '_specific_msg', '_type_info', '_typing', '_utils', 'abs', 'absolute', 'acos', 'acosh', 'add', 'all', 'allclose', 'amax', 'amin', 'angle', 'any', 'append', 'apply_along_axis', 'apply_over_axes', 'arange', 'arccos', 'arccosh', 'arcsin', 'arcsinh', 'arctan', 'arctan2', 'arctanh', 'argmax', 'argmin', 'argpartition', 'argsort', 'argwhere', 'around', 'array', 'array2string', 'array_equal', 'array_equiv', 'ar
# ...

# %%
__abc__

# %%
# print = 100

# %%
# print(10+20)

# %%
# Variable sand constant - is a name which may change the data associated with it over time in a program

# a = 10
# print(a, type(a))
# a = 'Python'
# print(a, type(a))
# Out:
# 10 <class 'int'>
# Python <class 'str'>

# %%
# Constant - Something which will not change over time

# Calculating area of a cricle - piXradiusXradius
# radius = float(input('Enter th eraidua in cm: '))
# PI = 3.14
# area = PI * radius * radius    # this line calculates the araea of a circle as per the formula
# print(area)

# Modules - constants.py
# Out:
# Enter th eraidua in cm: 12
# 452.15999999999997

# %%
# Comments in Python
# Single line comments  - # in the begining iof the comment line
# Multiline comments -



radius = float(input('Enter th eraidua in cm: '))
# '''PI = 3.14
# area = PI * radius * radius    # this line calculates the araea of a circle as per the formula
# print(area)'''
print(radius)
print(area)

# cmd + /    - Commenting with a single keystroke on mac
# ctrl + /   - Commenting with a single keystroke on windows
# Out:
# Enter th eraidua in cm: 12
# 12.0
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1213834421.py in <cell line: 0>()
#      10 # print(area)'''
#      11 print(radius)
# ---> 12 print(area)
#      13
#      14 # cmd + /    - Commenting with a single keystroke on mac
#
# NameError: name 'area' is not defined

# %%
# Expressions an d Statements in Python

# Expressions - is a combination of values, variables, operators and call to functions.
# need to be evaluated (it alwya s give some result or output)
# if we use print() for an expression then it evaluates the expression and prints the result
# Since expressions are always evaluated so that is why it is always written on right side of
      # assignment operators in assignment statement
# Simplest expression is a literal


# Statement - instructions written in the source code for execution
# Types of statements
# 1. Assignment Statewment
# 2. Compound assignment stattement
# 3. Conditional satement
# 4. Loop
# 5. Statements can be extended to one or more lines using paranthesis(), braces{}, square brackets[]
# , semi colon :, and continuation characters \

# %%
# 10 + 2 = 12
print(10+20)
# Out:
# 30

# %%
a = 10
for i in [10, 20, 30]:
  print(i)
# Out:
# 10
# 20
# 30

# %%
# Blocks and indentation
# # We need to prepare tea
# Ingredients - tea leaf, water, milk, sugar, gas, cardamom, ginger, strainer etc
# Steps :- light the gas, put the pan on gas, pour water, etc...

# Ingredients
#   - tea
#   - leaf,
#   - water,
#   - milk,
#   - sugar,
#   - gas,
#   - cardamom,
#   - ginger,
#   - strainer etc
# Steps
#   - light the gas,
#   - put the pan on gas,
#   - pour water,
#   - etc...

# {}

# Block making keywprds - if, elif, else, for, while, def, class, try, except, finally, open etc
# take 3 numbers from user and compare which one is larger
num1 = int(input('Enter first number: '))
num2 = int(input('Enter Second number: '))
num3 = int(input('Enter third number: '))
if num1 > num2 and num1 > num3:
  print(f'num1 = {num1} is greater')
  print(f'num2 = {num2} is smaller than num1 = {num1}')
  print(f'num3 = {num3} is smaller than num1 = {num1}')
elif num2 > num3:
    print(f'num2 = {num2} is greater')
    print(f'num1 = {num1} is smaller than num2 = {num2}')
    print(f'num3 = {num3} is smaller than num2 = {num2}')
else:
  print(f'num3 = {num3} is greater')
  print(f'num1 = {num1} is smaller than num3 = {num3}')
  print(f'num2 = {num2} is smaller than num3 = {num3}')
print('In the normal flow of the program')
print(num1)
print(num2)
print(num3)
# Out:
# Enter first number: 100
# Enter Second number: 90
# Enter third number: 9000
# num3 = 9000 is greater
# num1 = 100 is smaller than num3 = 9000
# num2 = 90 is smaller than num3 = 9000
# In the normal flow of the program
# 100
# 90
# 9000

# %%
# '10' + 2
int('10') + 2
# Out:
# 12

# %%
a = 10
b = 20
c = b+a
if a\
<b:
  print(a)
  print(b)
  print(b-a)
  print(a+b)
  if a+b == c:
    print(c)
    print(a)
    print(b)
    print(a+b)
# Out:
# 10
# 20
# 10
# 30
# 30
# 10
# 20
# 30

# %%
# Escape Sequence in Python
# \n - new line
# \t - horiazontal tab
# \v - vertical tab
# \ = we can write multi line strings
# \\ = it print \
# \' = it prints '
# \" = it prints "

# my_str = 'This is Python\'s class'
# print(my_str)
# my_str = "This is \"Python\" class"
# print(my_str)

my_str = 'C:\\User\\naveen'
print(my_str)
# Out:
# C:\User\naveen

# %%
How to differentiate created the variable and assigned the values to variable?
Below is the scenario:
------------------------
Developer A:
------------------------------
a=100;
/*
Business logic
*/

Developer B:
------------------------------
a = 'Welcome'
/*
Business logic
*/

Developer A:
---------------
/*
Method_name(a);
*/

Note: Both developer wrote there logic in same class as above sequence

1. Don't we think will cause an exception when we call the Method_name to pass
the value of developer A to perform some actions since this method is expecting the integer argument.

2. Don't we think its time consuming for developer B to find whether
variable is being created/used or not by developer A.

# %%
# Data Types
Fundamental Data Types
1. Integers
2. Float
3. Complex
4. Boolean
5. Strings
6. None
Derived Data Types
1. List
2. Tuple
3. Set and Frozenset
4. Dictionary
5. Bytes and Bytearray
etc

# %%
# Literals = Expressions = Object = Value = Data
# Integers - Any whole number without decimal point - 10, -10, 0
# 2. Default representation of any integer value is in decimal format - 0 to 9
# Only integers can be represented in binary, octal, in hexadecimal

# Binary - 0b or 0B, Allowed Digits - 0 and 1, bin(x) -> where x can be deimal, binary, octal or hexadecimal value
# Octal - 0o or 0O, Allowed Digits - 0 to 7, oct(x) -> where x can be deimal, binary, octal or hexadecimal value
# Hexadecimal - 0x or 0X, Allowed Digits - 0 to 9 and a/A to f/F, hex(x) -> where x can be deimal, binary, octal or hexadecimal value


# a = 10101
# b = 0b1011011
# print(b)

# num = 9876
# print(f'Decimal to Binary of {num}: {bin(num)}')
# print(f'Decimal to Octal of {num}: {oct(num)}')
# print(f'Decimal to hexadecimal of {num}: {hex(num)}')
# Out:
# Decimal to Binary of 9876: 0b10011010010100
# Decimal to Octal of 9876: 0o23224
# Decimal to hexadecimal of 9876: 0x2694

# %%
# int() - used to convert the value into integer type
# one level tyope casting is allowed

# values accepted in int()
# print(int(10))
# print(int(10.52))
# print(int('10'))
# print(int(0b10101))
# print(int(True))

# Values not accepted in int()
# print(int('10.20'))
# print(int(10+20j))
# print(int('A'))
# print(int('0b10101'))
# print(int('True'))

# %%
 # Float in python - # Any decimal value with a decimal point - 10.020, -10.20, 0.0009
 # Can be represented only using decimal format

 a = 109.90
#  print(a, type(a), id(a))
#  print(dir(a))
#  print(help(a))

# What all values float() can accept
# print(float(10))
# print(float(10.20))
# print(float('10'))
# print(float('10.20'))
# print(float(0b101010))
# print(float(True))


# print(float(10+20j))
# print(float('A'))
# print(float('0b1010101'))
# print(float('True'))

# int(obj)
# float(obj)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-2332360926.py in <cell line: 0>()
#      17
#      18 # print(float(10+20j))
# ---> 19 print(float('A'))
#      20 # print(float('0b1010101'))
#      21 # print(float('True'))
#
# ValueError: could not convert string to float: 'A'

# %%
# Complex NUmbers
# a+bj -> a is real part and b is imaginary part and value of j is square root of (-1)

num = 10+20j
# print(num, type(num), id(num))
# print(dir(num))
# print(help(num))

# accessing real and imaginary part
# print(f'Real part of num = {num} is {num.real}')
# print(f'Imaginary part of num = {num} is {num.imag}')


# complex(real, imag) -> real + imag X j
# complex(real) -> real + 0 X j

# Accepted value in complex function
# print(complex(10))
# print(complex(10.20))
# print(complex('10'))
# print(complex('10.20'))
# print(complex(0xface))
# print(complex(True))

# print(complex('0b10101'))
# print(complex('A'))
# print(complex('True'))


# 1. If first argument is string then complex() will not take 2nd argument
# 2. Second argument can never be passed as a string object

# print(complex(10, 20))
# print(complex(10.20, True))
# print(complex(0b10101, 0o5437))
# print(complex(True, False))

# print(complex(10, '20'))
# print(complex('10', 20))
# print(complex('10', '20'))

# print(complex(10+20j))
# print(complex('10+20j'))
print(complex(10+20j, 120)) # ----> 10+20j+120j


# complex(10, 20) -> 10+20j
# Out:
# (10+140j)

# %%
print(int('10'))
# print(int('10.20'))
print(float('10.20'))
# Out:
# 10
# 10.2

# %%
# print(complex(10+20j,120+20j))
# 10+20j+(120+20j)*j
# 10+20j+120j-20
# -10+140j

# %%
Programming
Mathemetaics
Domain KNowledge

# %%
sal = 10000

# %%
Naked Statistics -
Machine Learning in Data Science using Python by Nageshwar Rao
