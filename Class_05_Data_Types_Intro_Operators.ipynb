# %% [markdown]
# <a href="https://colab.research.google.com/github/Rajarajan1087/Learnbay/blob/main/Class_05_Data_Types_Intro_Operators.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Fundamental Data Types
#   1. Integers
#   2. Float
#   3. Complex
#   4. Boolean
#   5. Strings
#   6. None
# Derived Data Types
#   1. List
#   2. Tuple
#   3. Set and Frozen set
#   4. Dictionary
#   5. Byte and Bytearray

# %%
# Boolean Data Type - True, False
val = True
print(val, type(val))
# val = true
# print(val, type(val))
# Boolean to number
# True -> 1
# False -> 0

# Int -> 0 is false and rest all value is True
# Float -> 0.0 is false and rest all value is True
# Complex -> 0.0+0.0j is false and rest all value is True
# None -> None is always false
# String -> '' is false and rest all value is True
# List, Tuple, set, dictionary etc -> [], (), set(), {}... is false and rest all value is True

# bool(obj) -> based on object content it will be converted to bool type i.e True or False
print(bool(0), bool(-9))
print(bool(0.0), bool(-9.0))
print(bool(None))
print(bool(''), bool(' '))
print(bool([]), bool(()), bool(set()), bool({}))
# print(bool(None))
# print(bool([]))
print(bool([1]))
# print(bool([None]))

# is_married - True/False

print(10<20)
# Out:
# True <class 'bool'>
# False True
# False True
# False
# False True
# False False False False
# True
# True

# %%
# print(10+True)
# Out:
# 11

# %%
# String - '...', "...", '''...''', """..."""
# String is immutable - We can not modify
# Empty String - '', str()

# str1 = 'This is using single Quotation.'
# print(str1, type(str1))
# str2 = "This is using Double Quotation."
# print(str2, type(str2))
# str1 = '''This is using triple Quotation made of single quotes.'''
# print(str1, type(str1))
# str2 = """This is using triple Quotation made of double quotes."""
# print(str2, type(str2))

# my_str = 'This is Python's claSS'
# print(my_str)

# my_str = 'This is Python\'s class'
# print(my_str)
# my_str = "This is Python's class"
# print(my_str)

# my_str = "This is \"Python\" class"
# print(my_str)
# my_str = 'This is "Python" class'
# print(my_str)

# my_str = 'This is "Python" and \'Java\' class'
# print(my_str)

# my_str = '''This is "Python" and 'Java' class'''
# print(my_str)

# Triple quotation is also used for writing docstring
# whenever we write a function/class/methods we need to define the function/class/methods that what it does and it may expand to more than a line
# in that case we use triple quotation to write these documentation in techincal word it called docstring

# def sample_func():
#   '''This is a sample_func.
#   This does nothing.
#   It is created just for fun.'''
#   pass

# print(sample_func.__doc__)

# Option1 - writing multiline string using single /double quotation
# my_str = 'This is a sample_func.\n\
# This does nothing.\n\
# It is created just for fun.'
# print(my_str)

# my_str = '''This is a sample_func.
# This does nothing.
# It is created just for fun.'''
# print(my_str)

# String is a sequence it will be having indexing, slicing, concatenation, Repetiton
# 1. Sequences in python follows both +ve and -ve indexing
# 2. +ve index starts from 0 from LHS
# 3. -ve index starts from -1 from RHS

# my_str = 'This is Python class'
# print(my_str, len(my_str))

# %%
# help(print)
# print(print.__doc__)
# Out:
# Prints the values to a stream, or to sys.stdout by default.
#
#   sep
#     string inserted between values, default a space.
#   end
#     string appended after the last value, default a newline.
#   file
#     a file-like object (stream); defaults to the current sys.stdout.
#   flush
#     whether to forcibly flush the stream.

# %%
# Escape characters -
# \n
# \t
# \v
# \f
# \'
# \"

# %%
# List - Sequence
# [....]
# empty list - [], list()
# list(iterable) # Iterable - str, list, tuple, set, frozenset, dict, bytes, bytearray
# List is a mutable object - we can modify it

# lst1 = []
# lst2 = list()
# print(lst1, lst2, type(lst1), type(lst2))

# my_str1 = 'Python'
# print(my_str1, type(my_str1))
# lst1 = list(my_str1)
# print(lst1, type(lst1))

# print(list(10))
# print(list(10.20))
# print(list(10.20+20j))
# print(list(True))

# list([1,2, 3, 4, None, 'Python', [10, 20]])

# List is mutable

# Mutability
# Mutable - Modify - Item assignment is possible
# Immutable - Not Modify - Item assignment is not possible

lst1 = [1, 2, 3, 4]
print(lst1, type(lst1))
# Out:
# [1, 2, 3, 4] <class 'list'>

# %%
# -ve start from -1 from right side

# -6 -5 -4 -3 -2 -1
#  P  y  t  h  o  n


# Python
# 012345
# +ve starts from 0 from left side


# -4 -3 -2 -1
# [1, 2, 3, 4]
#  0  1  2  3

# %%
# Mutable - Modify - Item assignment is possible - id will not change
lst1 = [1, 2, 3, 4]
print('Before Operation')
print(lst1, id(lst1))
# Accessing the element/item in list/sequence - indexing
# print(lst1[1])
# # Accessing last element in the list
# print(lst1[-1])
print()
print('After Operation')
lst1[1] = 20
print(lst1, id(lst1))
# Out:
# Before Operation
# [1, 2, 3, 4] 132377355209472
#
# After Operation
# [1, 20, 3, 4] 132377355209472

# %%
# Immutable - Not Modify - Item assignment is not possible -
# Before operation and after operation value will not chnage and if we will try to
# change the value then new object shlould be created with new id

# str1 = 'This is Python class'
# print('Before Operation')
# print(str1, id(str1))
# print()
# print('After Operation')
# str1[6] = 'z'
# print(str1, id(str1))


# str1 = 'This is Python class'
# print('Before Operation')
# print(str1, id(str1))
# print()
# print('After Operation')
# res_str = str1.replace('s', 'z')
# print(str1, id(str1))
# print(res_str, id(res_str))



# str1 = 'This is Python class'
# print('Before Operation')
# print(str1, id(str1))
# print()
# print('After Operation')
# str1  = str1.replace('s', 'z')
# print(str1, id(str1))
# print(res_str, id(res_str))

# a = 10
# a = a+2
# print(a)

# lst1 = ['Python']
# # print(lst1[0])
# lst1[0][-1] = 'm'

# %%
# Mutable - Modify, Immutable - Not modify
# Mutable - Item Assignment is possible, etc list, dict, set etc
# When we do item assgnment or we try to make any changes in the mutable object changes will be made to original objects only
# that is why before and after the operation id are same for the object even after changes are done.


# Immutable - Item Assignment is not possible - etc string, tuple, frozenset etc

# %%
# lst1=["Python"]
# print(lst1[0],type(lst1[0]))
# # lst1[0][-1] ='m'
# # print(lst1) —>
# last 2 line should not work as its string object and it would not allow the assignment

# %%
# Tuple - sequence
# (...)
# empty Tuple - (), tuple()
# tuple(iterable)
# tuple is immutable - item assignment is not possible - modification is not possible

# tpl1 = tuple()
# tpl2 = ()
# print(tpl1, tpl2, type(tpl1), type(tpl2))

# tpl1 = tuple('Python')
# print(tpl1)
# tpl1 = tuple([1, 2, 3, 4])
# print(tpl1)
# tpl1 = tuple((1, 2, 3, 4))
# print(tpl1)

# Tuple is immutable
# tpl1 = (1, 2, 3, 4)
# tpl1[0] = 100
# print(tpl1)

# tpl1 = (1, 2, 3, [10, 20, 30])
# print(len(tpl1))

# tpl1 = (1, 2, 3, 4)
# print(tpl1, type(tpl1))

tpl1 = ()
print(tpl1, type(tpl1))
# Out:
# () <class 'tuple'>

# %%
# Set and frozenset

# Set - Collection of unique eleements - it will not allow duplicate elements
# It is not a sequence type - it will not support indexing, slicing, concatenation, repetition etc
# s1 = {10, 20, 30, 40, 10, 40, 30, 50, 100, 90, 10, 10, 20}
# print(s1, type(s1))

# s1 = set([10, 20, 30, 40, 10, 40, 30, 50, 100, 90, 10, 10, 20])
# print(s1, type(s1))
# print(s1[0])

# Empty set - using set() only
# s1 = {}
# print(s1, type(s1))

# s1 = set()
# print(s1, type(s1))

# set(iterable) -
# print(set([1, 2, 3, 4]))
# print(set((1, 2, 3, 4)))
# print(set('Python'))

# Mutability - modify - item assignment is possible - sequnece - string, list, tuple

# set is mutable -
s1 = set([10, 20, 30, 40, 10, 40, 30, 50, 100, 90, 10, 10, 20])
print('before Operation')
print(s1, id(s1))
print()
print('After Operation')
s1.add(9999)
print(s1,id(s1))
print(dir(s1))
# Out:
# before Operation
# {100, 40, 10, 50, 20, 90, 30} 132377356168640
#
# After Operation
# {100, 40, 10, 9999, 50, 20, 90, 30} 132377356168640
# ['__and__', '__class__', '__class_getitem__', '__contains__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__iand__', '__init__', '__init_subclass__', '__ior__', '__isub__', '__iter__', '__ixor__', '__le__', '__len__', '__lt__', '__ne__', '__new__', '__or__', '__rand__', '__reduce__', '__reduce_ex__', '__repr__', '__ror__', '__rsub__', '__rxor__', '__setattr__', '__sizeof__', '__str__', '__sub__', '__subclasshook__', '__xor__', 'add', 'clear', 'copy', 'difference', 'difference_update', 'discard', 'intersection', 'intersection_update', 'isdisjoint', 'issubset', 'issuperset', 'pop', 'remove', 'symmetric_difference', 'symmetric_difference_update', 'union', 'update']

# %%
lst1 = [1, 2, 3, 4]
print('before Operation')
print(lst1, id(lst1))
print()
print('After operation')
lst1.append(99)
print(lst1, id(lst1))
# Out:
# before Operation
# [1, 2, 3, 4] 132377355480128
#
# After operation
# [1, 2, 3, 4, 99] 132377355480128

# %%
# If object implements __iter__ method
# print(dir(str))
# print(dir(list))
# print(dir(set))
# print(dir(int))
# Out:
#   File "/tmp/ipython-input-3874092152.py", line 1
#     str))
#        ^
# SyntaxError: unmatched ')'

# %%
# for var in iterable:
#   pass
# for i in 'Python':
#   print(i)

# for i in 10:
#   print(i)

# %%
# Frozenset - immutable set
# Frozeset - Collection of unique eleements - it will not allow duplicate elements
# It is not a sequence type - it will not support indexing, slicing, concatenation, repetition etc

# frozenset(iterable)

# fz1 = frozenset('Python class')
# print(fz1, type(fz1))

# empty frozenset
# fz1 = frozenset()
# print(fz1)
# Out:
# frozenset()

# %%
# Dictionary -
# Dictionary - is not a sequence so does not follow indexing
# Dictionary is mutable object
# Dictionary is a collection of key:value pair

# d1 = {'key1':'Value1', 'key2':'Value2', 'key3':'Value3'....}
# st_marks = {'Mukesh':90, 'Suresh':98, 'Mahesh':78, 'Shiva':89}
# print(st_marks, type(st_marks))


# It is a collection of key:value pair
# Key and value is one element insiode a dictionary and are separated by a :
# Each elements are sepearted by a comma
# Key should be unique and only immutable objects
# Values can be anything
# We can access value using key but vice-versa is not possible

# d1 = {[1, 2, 3]:100}
# print(d1)
# d1 = {(1, 2, 3):[100]}
# print(d1)

# st_marks = {'Mukesh':90, 'Suresh':98, 'Mahesh':78, 'Shiva':89}
# print(st_marks, type(st_marks))
# print(st_marks['Mahesh'])

# Dictionary is mutable
# st_marks = {'Mukesh':90, 'Suresh':98, 'Mahesh':78, 'Shiva':89}
# print('Before Operation')
# print(st_marks, id(st_marks))
# print()
# print('After Operation')
# st_marks['Mahesh'] = 98
# print(st_marks, id(st_marks))


# empty dict
# d1 = {}
# print(d1, type(d1))
# d2 = dict()
# print(d2, type(d2))

# %%
# Operators in Python

1. Arithmetic Operators -> +, -, *, /(float Division), //(floor Division), %(Modulo Operator), **(Exponent)
2. Comparison Operator -> <, <=, >, >=
3. Equality Operator -> ==, !=
4. Logical Operator -> and, or, not
5. Bitwise Operator -> &, |, ^, ~, <<, >>
6. Assignment and compound assignment -> =, +=, -=, *=, /=, //=, %=, **=, &=, |=, ^=, <<=, >>=, ~=
7. Identity Operator - is, is not
8. membership operator - in, not in
9. Ternary Operator - expr1 if cond else expr2
10. Operator precedence

# %%
# Arithmetic -> +, -, *, /(Float Division), //(Floor Division), %(Modulo), **(Exponent)

a = 100
b = 3
# print(a+b)
# print(a-b)
# print(a*b)

# floor and ceil

# ceil - higest nearest whole number - ceil
# floor - lowet nearest whole number - floor

# ceil - 11, 11, -4
# 10.5, 10.9, -4.5
# floor - 10, 10, -5

# import math
# print(f"floor of 10.5 -> {math.floor(10.5)}")
# print(f"ceil of 10.5 -> {math.ceil(10.5)}")

# print(f"floor of 10.9 -> {math.floor(10.9)}")
# print(f"ceil of 10.9 -> {math.ceil(10.9)}")

# print(f"floor of -4.9 -> {math.floor(-4.9)}")
# print(f"ceil of -4.9 -> {math.ceil(-4.9)}")


# # float division - after dividing it returns a float value
# print(a/b)
# print(100/2)

# floor division - returns floor value of float division result
# print(a//b)

# Modulo operation - % - returns remainder after division
# print(a%b)

# Exponent - a**b -> a raise to the power b
print(100**3)
# Out:
# 1000000

# %%
# + with numbers - addition
# + with sequence - concatenation

# * with numbers - multiplication
# * with sequence - repetition

# Squence - String, list, tuple etc

# %%
# Concatenation(+) - When we perform (+)operation on sequence type then it is called concatenation
# Both the operand should be of same type(same sequence)
# This operator (Concatenation) returns a new object after operation, does not makke any changes to existing objects


# my_str1 = 'Python'
# my_str2 = 'Class'
# print('Before Operation')
# print(my_str1, id(my_str1))
# print(my_str2, id(my_str2))
# res_str = my_str1+my_str2
# print()
# print('After Operation')
# print(my_str1, id(my_str1))
# print(my_str2, id(my_str2))
# print(res_str, id(res_str))


# a = ['Abhishek', 10, 10.20]
# b = ['Learnbay']
# c = a+b
# print(a)
# print(b)
# print(c)


# my_str = "Python"
# my_lst = ['Learnbay']
# print(my_str+my_lst)    # TypeError: can only concatenate str (not "list") to str



# my_str = 'Python'
# print(my_str+3)          # TypeError: can only concatenate str (not "int") to str


# Repetition
# Repetition - *
# One of the operand should be seqtype and other should be integer
# This Operator returns a new object i.e. does not make any changes to existing object

a = 'Learnbay '
b = 3
c = a*b
print(a)
print(b)
print(c)
# Out:
# Learnbay
# 3
# Learnbay Learnbay Learnbay
